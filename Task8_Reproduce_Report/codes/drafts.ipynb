# %%
import pandas as pd

inv_total_tradingday_df = pd.read_csv('/home/dalong/bruce/Task8_Reproduce_Report/data/inventory_total_TradingDays.csv', index_col=0)

# %%
inv_total_tradingday_df
# Out:
#                  al      cu      ni      pb     sn      zn        bu      l  \
# 2010/1/4    4624425  634252  158424  146775  26795  651436       NaN  34135
# 2010/1/5    4624125  637733  158424  147175  26795  651411       NaN  34135
# 2010/1/6    4619850  640757  158388  147850  26795  651911       NaN  34435
# 2010/1/7    4615400  640683  158814  149150  26860  652737       NaN  34435
# 2010/1/8    4613400  643732  158982  149375  26910  654965       NaN  18585
# ...             ...     ...     ...     ...    ...     ...       ...    ...
# 2017/12/25  1808745  446231  405878  178095   6731  197692  177450.0  21230
# 2017/12/26  1809196  448408  405878  178070   6803  197392  173150.0  19495
# 2017/12/27  1809095  449308  404000  177470   6764  195418  173150.0  19495
# 2017/12/28  1809891  450586  402788  176939   6690  193643  170150.0  19495
# 2017/12/29  1811353  455201  399728  176790   6680  191439  182980.0  19195
#
# ...

# %%
rolling = 2

signal_df = inv_total_tradingday_df.diff(rolling - 1) / inv_total_tradingday_df.shift(rolling - 1)

# %%
signal_df
# Out:
#                   al        cu        ni        pb        sn        zn  \
# 2010/1/4         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/5   -0.000065  0.005488  0.000000  0.002725  0.000000 -0.000038
# 2010/1/6   -0.000538  0.005078 -0.000125  0.003749  0.000000  0.000405
# 2010/1/7   -0.000709  0.002990  0.001006  0.005776  0.000975  0.000751
# 2010/1/8   -0.000618  0.003573  0.001023  0.004370  0.001267  0.001628
# ...              ...       ...       ...       ...       ...       ...
# 2017/12/25  0.000956  0.002166 -0.000307  0.001694 -0.010753 -0.008262
# 2017/12/26  0.000828  0.002659 -0.000251  0.001361 -0.006853 -0.007036
# 2017/12/27  0.000667  0.002541 -0.001047  0.000501 -0.006649 -0.007575
# 2017/12/28  0.000626  0.002596 -0.001402 -0.000134 -0.007430 -0.007849
# 2017/12/29  0.000659  0.003986 -0.002528 -0.000263 -0.006351 -0.008492
#
#                   bu         l        MA        pp  ...        FG        hc  \
# ...

# %%
import pandas as pd

signal_df = pd.DataFrame.ewm(signal_df, span=10).mean()

# %%
pd.DataFrame.ewm(signal_df, span=10).mean()
# Out:
#                   al        cu        ni        pb        sn        zn  \
# 2010/1/4         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/5   -0.000065  0.005488  0.000000  0.002725  0.000000 -0.000038
# 2010/1/6   -0.000538  0.005078 -0.000125  0.003749  0.000000  0.000405
# 2010/1/7   -0.000709  0.002990  0.001006  0.005776  0.000975  0.000751
# 2010/1/8   -0.000618  0.003573  0.001023  0.004370  0.001267  0.001628
# ...              ...       ...       ...       ...       ...       ...
# 2017/12/25  0.000956  0.002166 -0.000307  0.001694 -0.010753 -0.008262
# 2017/12/26  0.000828  0.002659 -0.000251  0.001361 -0.006853 -0.007036
# 2017/12/27  0.000667  0.002541 -0.001047  0.000501 -0.006649 -0.007575
# 2017/12/28  0.000626  0.002596 -0.001402 -0.000134 -0.007430 -0.007849
# 2017/12/29  0.000659  0.003986 -0.002528 -0.000263 -0.006351 -0.008492
#
#                   bu         l        MA        pp  ...        FG        hc  \
# ...

# %%
import numpy as np

pd.Series([np.nan, 2, 3, -2, -6]).dropna().sort_values(ascending=False)
# Out:
# 2    3.0
# 1    2.0
# 3   -2.0
# 4   -6.0
# dtype: float64

# %%
pd.Series([np.nan, 2, 3, -2, -6]).sort_values()
# Out:
# 4   -6.0
# 3   -2.0
# 1    2.0
# 2    3.0
# 0    NaN
# dtype: float64
