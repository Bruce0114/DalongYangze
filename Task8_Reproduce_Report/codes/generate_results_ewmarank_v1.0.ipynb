# %%
import sys
path = '/Users/apple/desktop/Yangze_Investment/Task8_Reproduce_Report/Task8_20200304_2022'
sys.path.append(f'{path}/self_defined')

# %%
from calc_inv_data import calc_inv_data
from process_total_inv import process_total_inv
from generate_inv_signal_seprank import generate_inv_signal_seprank
from generate_inv_signal_unirank import generate_inv_signal_unirank
from generate_inv_signal_allinone import generate_inv_signal_allinone
from generate_ret_fnv import generate_ret_fnv

# %%
# %%time

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [i for i in range(10, 110, 10)]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')
    
    annualized_ret_pair_df = pd.DataFrame(annualized_ret_pair)
    
    annualized_ret_df = pd.concat([annualized_ret_df, annualized_ret_pair_df], axis=1)
    
annualized_ret_df.index = ['annualized_ret', 'annualized_ret_DeductTC']
annualized_ret_df.columns = ewma_days_list

annualized_ret_df
# Out:
# Login YzData Success
# CPU times: user 2min 36s, sys: 805 ms, total: 2min 37s
# Wall time: 2min 59s
#                             10      20      30      40      50      60   \
# annualized_ret           0.0325  0.0176  0.0124  0.0137  0.0117  0.0097
# annualized_ret_DeductTC  0.0115  0.0041  0.0020  0.0047  0.0033  0.0017
#
#                             70      80      90      100
# annualized_ret           0.0229  0.0192  0.0207  0.0034
# annualized_ret_DeductTC  0.0160  0.0128  0.0146 -0.0021

# %%
annualized_ret_df.to_csv(f'{path}/results/annualized_ret_EWMARank_20170731_df.csv')

# %%
# %%time

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [1, 3, 5]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')
    
    annualized_ret_pair_df = pd.DataFrame(annualized_ret_pair)
    
    annualized_ret_df = pd.concat([annualized_ret_df, annualized_ret_pair_df], axis=1)
    
annualized_ret_df.index = ['annualized_ret', 'annualized_ret_DeductTC']
annualized_ret_df.columns = ewma_days_list

annualized_ret_df
# Out:
# Login YzData Success
# CPU times: user 47.5 s, sys: 244 ms, total: 47.7 s
# Wall time: 1min 12s
#                               1       3       5
# annualized_ret           0.0473  0.0439  0.0389
# annualized_ret_DeductTC -0.0393 -0.0005  0.0064

# %%
annualized_ret_df.to_csv(f'{path}/results/annualized_ret_EWMARank_20170731_R135_df.csv')

# %%
# %%time

# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_cumulative_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [i for i in range(10, 110, 10)]

cumulative_ret_2017_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    cumulative_ret_pair_2017 = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')
    
    cumulative_ret_pair_2017_df = pd.DataFrame(cumulative_ret_pair_2017)
    
    cumulative_ret_2017_df = pd.concat([cumulative_ret_2017_df, cumulative_ret_pair_2017_df], axis=1)
    
cumulative_ret_2017_df.index = ['cumulative_ret', 'cumulative_ret_DeductTC']
cumulative_ret_2017_df.columns = ewma_days_list

cumulative_ret_2017_df
# Out:
# Login YzData Success
# CPU times: user 2min 33s, sys: 773 ms, total: 2min 34s
# Wall time: 2min 56s
#                             10      20      30      40      50      60   \
# cumulative_ret           0.0406  0.0098  0.0797  0.0519  0.0464  0.0440
# cumulative_ret_DeductTC  0.0286  0.0020  0.0728  0.0463  0.0412  0.0382
#
#                             70      80      90      100
# cumulative_ret           0.0746  0.0559  0.0889  0.0847
# cumulative_ret_DeductTC  0.0697  0.0516  0.0847  0.0813

# %%
cumulative_ret_2017_df.to_csv(f'{path}/results/cumulative_ret_2017_EWMARank_df.csv')

# %%
# %%time

# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_cumulative_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [1, 3, 5]

cumulative_ret_2017_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    cumulative_ret_pair_2017 = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')
    
    cumulative_ret_pair_2017_df = pd.DataFrame(cumulative_ret_pair_2017)
    
    cumulative_ret_2017_df = pd.concat([cumulative_ret_2017_df, cumulative_ret_pair_2017_df], axis=1)
    
cumulative_ret_2017_df.index = ['cumulative_ret', 'cumulative_ret_DeductTC']
cumulative_ret_2017_df.columns = ewma_days_list

cumulative_ret_2017_df
# Out:
# Login YzData Success
# CPU times: user 49.7 s, sys: 372 ms, total: 50.1 s
# Wall time: 1min 14s
#                               1       3       5
# cumulative_ret           0.1348  0.0300  0.0126
# cumulative_ret_DeductTC  0.0774  0.0045 -0.0063

# %%
cumulative_ret_2017_df.to_csv(f'{path}/results/cumulative_ret_2017_EWMARank_R135_df.csv')

# %%
# %%time

# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_portfolio_df'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [90]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    portfolio_dailyret_df = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

portfolio_dailyret_df
# Out:
# Login YzData Success
# CPU times: user 17.9 s, sys: 253 ms, total: 18.1 s
# Wall time: 39.4 s
#             daily_ret_portfolio  ret_plus1  transaction_cost  \
# timestamp
# 2010-01-06             0.000000   1.000000         -0.000000
# 2010-01-07             0.004329   1.004329         -0.000300
# 2010-01-08             0.004467   1.004467         -0.000150
# 2010-01-11             0.000334   1.000334         -0.000225
# 2010-01-12             0.000212   1.000212         -0.000150
# 2010-01-13            -0.000433   0.999567         -0.000000
# 2010-01-14            -0.003287   0.996713         -0.000000
# 2010-01-15             0.003114   1.003114         -0.000000
# 2010-01-18             0.004047   1.004047         -0.000000
# 2010-01-19            -0.003314   0.996686         -0.000000
# 2010-01-20            -0.001046   0.998954         -0.000000
# 2010-01-21             0.000084   1.000084         -0.000075
# 2010-01-22             0.008262   1.008262         -0.000075
# 2010-01-25            -0.000876   0.999124         -0.000000
# 2010-01-26            -0.000948   0.999052         -0.000075
# 2010-01-27            -0.000027   0.999973         -0.000000
# 2010-01-28             0.002024   1.002024         -0.000000
# 2010-01-29             0.001018   1.001018         -0.000075
# 2010-02-01             0.007346   1.007346         -0.000000
# 2010-02-02            -0.001589   0.998411         -0.000075
# 2010-01-29            1.000943        1.018039                 1.016897
# 2010-02-01            1.007346        1.025518                 1.024368
# 2010-02-02            0.998336        1.023888                 1.022663
# 2010-02-03            0.998849        1.022787                 1.021486
# 2010-02-04            1.005841        1.028761                 1.027452
# 2010-02-05            1.007282        1.036329                 1.034934
# 2010-02-08            1.000516        1.036941                 1.035468
# 2010-02-09            1.000063        1.037006                 1.035533
# 2010-02-10            0.994938        1.031757                 1.030291
# 2010-02-11            0.992492        1.024011                 1.022556
# 2010-02-12            0.992833        1.016749                 1.015227
# 2010-02-22            0.994696        1.011432                 1.009842
# 2010-02-23            1.002056        1.013511                 1.011918
# ...                        ...             ...                      ...
# 2017-06-20            1.001215        1.153805                 1.103536
# 2017-06-21            0.996910        1.150326                 1.100126
# 2017-06-22            0.999702        1.150070                 1.099798
# 2017-06-23            0.999169        1.149114                 1.098884
# 2017-06-26            1.002712        1.152317                 1.101864
# 2017-06-27            0.998507        1.150769                 1.100219
# 2017-06-28            1.003814        1.155158                 1.104415
# 2017-06-29            0.996231        1.150804                 1.100253
# 2017-06-30            0.997279        1.147759                 1.097259
# 2017-07-03            1.004733        1.153191                 1.102452
# 2017-07-04            1.009314        1.163933                 1.112721
# 2017-07-05            0.998946        1.162706                 1.111548
# 2017-07-06            0.997670        1.159997                 1.108958
# 2017-07-07            0.998428        1.158260                 1.107214
# 2017-07-10            1.003962        1.162849                 1.111601
# 2017-07-11            1.003122        1.166567                 1.115072
# 2017-07-12            1.007315        1.175101                 1.123229
# 2017-07-13            0.996652        1.171167                 1.119469
# 2017-07-14            0.998585        1.169510                 1.117885
# 2017-07-17            1.000635        1.170253                 1.118595
# 2017-07-18            0.994314        1.163686                 1.112235
# 2017-07-19            0.990097        1.152163                 1.101221
# 2017-07-20            0.992174        1.143146                 1.092603
# 2017-07-21            0.999609        1.142699                 1.092176
# 2017-07-24            0.997428        1.139760                 1.089366
# 2017-07-25            1.000333        1.140225                 1.089729
# 2017-07-26            1.007752        1.149064                 1.098176
# 2017-07-27            0.999242        1.148193                 1.097343
# 2017-07-28            1.004060        1.152854                 1.101798
# 2017-07-31            1.012509        1.167274                 1.115580
#
# [1838 rows x 6 columns]

# %%
portfolio_dailyret_df.to_csv(f'{path}/results/portfolio_dailyret_EWMARank_20170731_S{ewma_days}_df.csv')

# %%
# %%time

# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_portfolio_df'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling = 2

ewma_days_list = [100]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for ewma_days in ewma_days_list:
    
    # main function call
    signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)
    
    portfolio_dailyret_df = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

portfolio_dailyret_df
# Out:
# Login YzData Success
# CPU times: user 18.7 s, sys: 268 ms, total: 18.9 s
# Wall time: 38.4 s
#             daily_ret_portfolio  ret_plus1  transaction_cost  \
# timestamp
# 2010-01-06             0.000000   1.000000         -0.000000
# 2010-01-07             0.004329   1.004329         -0.000300
# 2010-01-08             0.004467   1.004467         -0.000150
# 2010-01-11             0.000334   1.000334         -0.000225
# 2010-01-12             0.000212   1.000212         -0.000150
# 2010-01-13            -0.000433   0.999567         -0.000000
# 2010-01-11            1.000109        1.009153                 1.008474
# 2010-01-12            1.000062        1.009367                 1.008537
# 2010-01-13            0.999567        1.008930                 1.008100
# 2010-01-14            0.996713        1.005613                 1.004786
# 2010-01-15            1.003114        1.008745                 1.007916
# 2010-01-18            1.004047        1.012828                 1.011995
# 2010-01-19            0.996686        1.009471                 1.008641
# 2010-01-20            0.998954        1.008416                 1.007586
# 2010-01-21            1.000009        1.008500                 1.007595
# 2010-01-22            1.008187        1.016832                 1.015843
# 2010-01-25            0.999124        1.015941                 1.014954
# 2010-01-26            0.998977        1.014978                 1.013915
# 2010-01-27            0.999973        1.014950                 1.013887
# 2010-01-28            1.002024        1.017005                 1.015940
# 2010-01-29            1.000943        1.018039                 1.016897
# 2010-02-01            1.007346        1.025518                 1.024368
# 2010-02-02            0.998336        1.023888                 1.022663
# 2010-02-03            0.998849        1.022787                 1.021486
# 2010-02-04            1.005841        1.028761                 1.027452
# 2010-02-05            1.007282        1.036329                 1.034934
# 2010-02-08            1.000516        1.036941                 1.035468
# 2010-02-09            1.000063        1.037006                 1.035533
# 2010-02-10            0.994938        1.031757                 1.030291
# 2010-02-11            0.992492        1.024011                 1.022556
# 2010-02-12            0.992833        1.016749                 1.015227
# 2010-02-22            0.994696        1.011432                 1.009842
# 2010-02-23            1.002056        1.013511                 1.011918
# ...                        ...             ...                      ...
# 2017-06-20            1.002052        1.030954                 0.989372
# 2017-06-21            0.996001        1.026831                 0.985415
# 2017-06-22            1.001063        1.028000                 0.986463
# 2017-06-23            0.999044        1.027017                 0.985519
# 2017-06-26            0.998671        1.025729                 0.984209
# 2017-06-27            0.999149        1.024933                 0.983372
# 2017-06-28            1.005965        1.031046                 0.989238
# 2017-06-29            0.998809        1.029819                 0.988060
# 2017-06-30            0.996059        1.025838                 0.984166
# 2017-07-03            1.004601        1.030635                 0.988694
# 2017-07-04            1.006376        1.037206                 0.994998
# 2017-07-05            0.997499        1.034612                 0.992510
# 2017-07-06            0.996908        1.031412                 0.989440
# 2017-07-07            0.995805        1.027086                 0.985290
# 2017-07-10            1.002694        1.029853                 0.987945
# 2017-07-11            1.002001        1.031914                 0.989921
# 2017-07-12            1.003236        1.035253                 0.993125
# 2017-07-13            1.001101        1.036393                 0.994218
# 2017-07-14            0.996936        1.033295                 0.991172
# 2017-07-17            1.003386        1.036794                 0.994528
# 2017-07-18            0.997344        1.034118                 0.991886
# 2017-07-19            0.993085        1.026967                 0.985028
# 2017-07-20            0.986412        1.013013                 0.971643
# 2017-07-21            0.998804        1.011801                 0.970481
# 2017-07-24            0.995943        1.007696                 0.966544
# 2017-07-25            1.001183        1.008889                 0.967688
# 2017-07-26            1.006895        1.015845                 0.974360
# 2017-07-27            1.000129        1.015976                 0.974486
# 2017-07-28            1.000774        1.016763                 0.975240
# 2017-07-31            1.009021        1.025935                 0.984038
#
# [1838 rows x 6 columns]

# %%
portfolio_dailyret_df.to_csv(f'{path}/results/portfolio_dailyret_EWMARank_20170731_S{ewma_days}_df.csv')

# %%
# %%time

# EWMA Matrix - Annualized Return - Without Transaction Cost Deducted

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling_list = [i for i in range(10, 110, 10)]

ewma_days_list = [i for i in range(20, 110, 10)]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for rolling in rolling_list:
    
    annualized_ret_list = []

    for ewma_days in ewma_days_list:

        # main function call
        signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)

        annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

        annualized_ret_list.append(annualized_ret_pair[0])  # position '0': no transaction cost deducted

    annualized_ret_df = pd.concat([annualized_ret_df, pd.DataFrame(annualized_ret_list)], axis=1)
    
# re-label row and column indices
annualized_ret_df.index = ewma_days_list
annualized_ret_df.columns = rolling_list
# rename row and column indices
annualized_ret_df.index.name = 'ewma_days'
annualized_ret_df.columns.name = 'rolling'

annualized_ret_df
# Out:
# Login YzData Success
# CPU times: user 23min 12s, sys: 7.48 s, total: 23min 19s
# Wall time: 23min 46s
# rolling       10      20      30      40      50      60      70      80   \
# ewma_days
# 20         0.0001 -0.0005  0.0129  0.0131  0.0138  0.0229  0.0339  0.0293
# 30        -0.0114  0.0085  0.0221  0.0385  0.0448  0.0288  0.0204  0.0195
# 40        -0.0043  0.0171  0.0362  0.0461  0.0346  0.0272  0.0291  0.0273
# 50         0.0169  0.0286  0.0437  0.0408  0.0229  0.0287  0.0320  0.0374
# 60         0.0316  0.0260  0.0435  0.0242  0.0278  0.0372  0.0366  0.0331
# 70         0.0396  0.0164  0.0386  0.0194  0.0217  0.0356  0.0260  0.0289
# 80         0.0314  0.0231  0.0239  0.0053  0.0133  0.0362  0.0349  0.0356
# 90         0.0323  0.0153  0.0099  0.0055  0.0240  0.0375  0.0282  0.0314
# 100        0.0296  0.0091  0.0053  0.0045  0.0233  0.0271  0.0260  0.0289
#
# rolling       90      100
# ewma_days
# 20         0.0137 -0.0004
# 30         0.0175  0.0082
# 40         0.0267  0.0311
# 50         0.0443  0.0466
# 60         0.0455  0.0340
# 70         0.0425  0.0364
# 80         0.0525  0.0375
# 90         0.0510  0.0363
# 100        0.0511  0.0355

# %%
annualized_ret_df.to_csv(f'{path}/results/annualized_ret_df_EWMAMatrix.csv')

# %%
# %%time

# EWMA Matrix - Annualized Return - Without Transaction Cost Deducted

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling_list = [i for i in range(10, 110, 10)]

ewma_days_list = [1, 3, 5, 10, 15]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for rolling in rolling_list:
    
    annualized_ret_list = []

    for ewma_days in ewma_days_list:

        # main function call
        signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)

        annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

        annualized_ret_list.append(annualized_ret_pair[0])

    annualized_ret_df = pd.concat([annualized_ret_df, pd.DataFrame(annualized_ret_list)], axis=1)
    
# re-label row and column indices
annualized_ret_df.index = ewma_days_list
annualized_ret_df.columns = rolling_list
# rename row and column indices
annualized_ret_df.index.name = 'ewma_days'
annualized_ret_df.columns.name = 'rolling'

annualized_ret_df
# Out:
# Login YzData Success
# CPU times: user 12min 38s, sys: 3.51 s, total: 12min 41s
# Wall time: 13min 3s
# rolling       10      20      30      40      50      60      70      80   \
# ewma_days
# 1          0.0459  0.0062  0.0052  0.0301  0.0196  0.0229  0.0212  0.0342
# 3          0.0442  0.0143  0.0140  0.0223  0.0100  0.0161  0.0208  0.0291
# 5          0.0375  0.0099  0.0103  0.0121 -0.0046  0.0157  0.0189  0.0213
# 10         0.0278 -0.0018  0.0047  0.0181 -0.0004  0.0119  0.0147  0.0175
# 15         0.0032 -0.0046  0.0143  0.0101  0.0002  0.0153  0.0223  0.0277
#
# rolling       90      100
# ewma_days
# 1          0.0468  0.0338
# 3          0.0458  0.0217
# 5          0.0369  0.0156
# 10         0.0221  0.0096
# 15         0.0165  0.0059

# %%
annualized_ret_df.to_csv(f'{path}/results/annualized_ret_df_EWMAMatrix1351015.csv')

# %%
# %%time

# EWMA Matrix - Annualized Return - Without Transaction Cost Deducted

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling_list = [5]

ewma_days_list = [1, 3, 5, 10, 15] + [i for i in range(20, 110, 10)]

annualized_ret_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for rolling in rolling_list:
    
    annualized_ret_list = []

    for ewma_days in ewma_days_list:

        # main function call
        signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)

        annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

        annualized_ret_list.append(annualized_ret_pair[0])

    annualized_ret_df = pd.concat([annualized_ret_df, pd.DataFrame(annualized_ret_list)], axis=1)
    
# re-label row and column indices
annualized_ret_df.index = ewma_days_list
annualized_ret_df.columns = rolling_list
# rename row and column indices
annualized_ret_df.index.name = 'ewma_days'
annualized_ret_df.columns.name = 'rolling'

annualized_ret_df
# Out:
# Login YzData Success
# CPU times: user 3min 38s, sys: 1.11 s, total: 3min 39s
# Wall time: 4min 1s
# rolling         5
# ewma_days
# 1          0.0380
# 3          0.0293
# 5          0.0231
# 10         0.0304
# 15         0.0348
# 20         0.0174
# 30         0.0159
# 40         0.0134
# 50         0.0134
# 60         0.0244
# 70         0.0398
# 80         0.0429
# 90         0.0347
# 100        0.0354

# %%
annualized_ret_df.to_csv(f'{path}/results/annualized_ret_df_EWMAMatrixR5.csv')

# %%
# %%time

# EWMA Matrix - Annualized Return - With Transaction Cost Deducted

# import sys
# import math
# # import xlwings
# import numpy as np
import pandas as pd
from yzutil import YzDataClient


# initiate data api obj
yz = YzDataClient('bruce@yangzeinvest.com', 'bruce123')

# load data
inv_index_tb = pd.read_csv(f'{path}/data/inventory_data_index.csv')
futures_data_df = pd.read_csv(f'{path}/data/futures_data.csv', index_col=0)

# set parameters
SIG_THRESHOLD = 0.2

mode = 'ret_annualized_pair'

shift_inv, shift_sig = 'shift_yes', 'shift_yes'

signal_type = 'ewma_universal_rank'

rolling_list = [5] + [i for i in range(10, 110, 10)]

ewma_days_list = [1, 3, 5, 10, 15] + [i for i in range(20, 110, 10)]

annualized_ret_DeductTC_df = pd.DataFrame()

# main function calls
inv_total_tradingday_df = process_total_inv(inv_index_tb, yz, shift_inv)

for rolling in rolling_list:
    
    annualized_ret_list = []

    for ewma_days in ewma_days_list:

        # main function call
        signal_df = generate_inv_signal_allinone(inv_total_tradingday_df, rolling, SIG_THRESHOLD, signal_type, span=ewma_days)

        annualized_ret_pair = generate_ret_fnv(inv_index_tb, futures_data_df, signal_df, shift_sig, mode, '2017-07-31')

        annualized_ret_list.append(annualized_ret_pair[1])  # position '1': transaction cost deducted

    annualized_ret_DeductTC_df = pd.concat([annualized_ret_DeductTC_df, pd.DataFrame(annualized_ret_list)], axis=1)
    
# re-label row and column indices
annualized_ret_DeductTC_df.index = ewma_days_list
annualized_ret_DeductTC_df.columns = rolling_list
# rename row and column indices
annualized_ret_DeductTC_df.index.name = 'ewma_days'
annualized_ret_DeductTC_df.columns.name = 'rolling'

annualized_ret_DeductTC_df
# Out:
# Login YzData Success
# CPU times: user 37min 56s, sys: 8.19 s, total: 38min 4s
# Wall time: 38min 30s
# rolling       5       10      20      30      40      50      60      70   \
# ewma_days
# 1          0.0004  0.0243 -0.0074 -0.0051  0.0211  0.0117  0.0152  0.0145
# 3          0.0053  0.0288  0.0038  0.0059  0.0152  0.0038  0.0101  0.0153
# 5          0.0035  0.0240  0.0009  0.0032  0.0059 -0.0103  0.0103  0.0143
# 10         0.0162  0.0173 -0.0093 -0.0014  0.0127 -0.0052  0.0075  0.0105
# 15         0.0231 -0.0059 -0.0111  0.0089  0.0054 -0.0041  0.0114  0.0185
# 20         0.0079 -0.0073 -0.0061  0.0081  0.0087  0.0100  0.0192  0.0304
# 30         0.0080 -0.0175  0.0037  0.0177  0.0346  0.0412  0.0255  0.0172
# 40         0.0067 -0.0098  0.0126  0.0323  0.0426  0.0313  0.0241  0.0264
# 50         0.0072  0.0117  0.0244  0.0401  0.0373  0.0197  0.0258  0.0295
# 60         0.0188  0.0270  0.0221  0.0402  0.0211  0.0249  0.0345  0.0342
# 70         0.0347  0.0351  0.0127  0.0353  0.0165  0.0191  0.0332  0.0239
# 80         0.0381  0.0274  0.0197  0.0209  0.0028  0.0108  0.0341  0.0328
# 90         0.0302  0.0286  0.0122  0.0071  0.0031  0.0216  0.0355  0.0262
# 100        0.0313  0.0263  0.0061  0.0026  0.0023  0.0212  0.0251  0.0241
#
# rolling       80      90      100
# ewma_days
# 1          0.0279  0.0407  0.0284
# 3          0.0244  0.0409  0.0171
# 5          0.0170  0.0329  0.0115
# 10         0.0138  0.0189  0.0061
# 15         0.0243  0.0135  0.0029
# 20         0.0263  0.0108 -0.0032
# 30         0.0167  0.0149  0.0057
# 40         0.0246  0.0243  0.0287
# 50         0.0349  0.0420  0.0445
# 60         0.0308  0.0434  0.0320
# 70         0.0269  0.0406  0.0347
# 80         0.0337  0.0507  0.0360
# 90         0.0295  0.0493  0.0347
# 100        0.0272  0.0495  0.0342

# %%
annualized_ret_DeductTC_df.to_csv(f'{path}/results/annualized_ret_DeductTC_df_EWMAMatrix.csv')
