# %%
import pandas as pd

inv_total_tradingday_df = pd.read_csv('/Users/apple/desktop/Yangze_Investment/Task8_Reproduce_Report/outputs/inventory_total_TradingDays.csv', index_col=0)

# %%
col_index = inv_total_tradingday_df.columns
col_shift_index = pd.Series(col_index).map(lambda x: x + '_shift')

# %%
rolling = 10

inv_total_tradingday_df[col_shift_index] = inv_total_tradingday_df.shift(rolling - 1)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

inv_total_tradingday_df.diff(9)
# Out:
#                  al       cu      ni       pb      sn       zn       bu  \
# 2010/1/5        NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/6        NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/7        NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/8        NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/11       NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/12       NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/13       NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/14       NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/15       NaN      NaN     NaN      NaN     NaN      NaN      NaN
# 2010/1/18  -44825.0  22623.0  3240.0   4175.0   565.0  15244.0      NaN
# 2010/1/19    3325.0  22897.0  3234.0   3575.0   605.0  14692.0      NaN
# 2010/1/20    6825.0  20965.0  2478.0   3025.0   565.0  14667.0      NaN
# ...

# %%
inv_total_tradingday_df.shift(9)
# Out:
#                    al        cu        ni        pb       sn        zn  \
# 2010/1/5          NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/6          NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/7          NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/8          NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/11         NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/12         NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/13         NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/14         NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/15         NaN       NaN       NaN       NaN      NaN       NaN
# 2010/1/18   4624125.0  637733.0  158424.0  147175.0  26795.0  651411.0
# 2010/1/19   4619850.0  640757.0  158388.0  147850.0  26795.0  651911.0
# 2010/1/20   4615400.0  640683.0  158814.0  149150.0  26860.0  652737.0
# ...

# %%
inv_total_tradingday_df.diff(9) / inv_total_tradingday_df.shift(9)
# Out:
#                   al        cu        ni        pb        sn        zn  \
# 2010/1/5         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/6         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/7         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/8         NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/11        NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/12        NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/13        NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/14        NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/15        NaN       NaN       NaN       NaN       NaN       NaN
# 2010/1/18  -0.009694  0.035474  0.020451  0.028368  0.021086  0.023402
# 2010/1/19   0.000720  0.035734  0.020418  0.024180  0.022579  0.022537
# 2010/1/20   0.001479  0.032723  0.015603  0.020282  0.021035  0.022470
# ...

# %%
# Out:
#                       al            cu           ni           pb          sn  \
# 2010/1/5             NaN           NaN          NaN          NaN         NaN
# 2010/1/6             NaN           NaN          NaN          NaN         NaN
# 2010/1/7             NaN           NaN          NaN          NaN         NaN
# 2010/1/8             NaN           NaN          NaN          NaN         NaN
# 2010/1/11            NaN           NaN          NaN          NaN         NaN
# 2010/1/12            NaN           NaN          NaN          NaN         NaN
# 2010/1/13            NaN           NaN          NaN          NaN         NaN
# 2010/1/14            NaN           NaN          NaN          NaN         NaN
# 2010/1/15            NaN           NaN          NaN          NaN         NaN
# 2010/1/18   14907.825359   8635.190591  1366.718845  1287.288278  197.090645
# 2010/1/19   14768.787705   8527.978281  1357.562522  1067.720833  228.300484
# ...

# %%
inv_total_tradingday_df.columns.get_loc('al')
# Out:
# 0

# %%
inv_total_tradingday_df.columns
# Out:
# pandas.core.indexes.base.Index

# %%
inv_total_tradingday_df.columns.get_values()
# Out:
# numpy.ndarray

# %%
inv_total_tradingday_df.index.get_loc('2010/1/18')
# Out:
# 9
